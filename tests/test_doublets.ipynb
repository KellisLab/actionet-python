# %%
import actionet
import scanpy as sc
import anndata
import pandas as pd
import numpy as np

import lets_plot
lets_plot.LetsPlot.setup_html(no_js=True)

# %%
# adata = anndata.read_h5ad("../data/test_adata.h5ad")
adata = anndata.read_h5ad("/private/tmp/test_scrublet_output.h5ad", backed="r")

# %%
# doublet_calls = actionet.call_doublets(adata, sim_doublet_ratio=1, expected_doublet_rate=0.08)
adata

# %%
actionet.plot_umap_raster(adata, color='scrublet_predicted_doublet', basis='umap', color_type="categorical")

# %%
actionet.plot_umap_raster(adata, color='scrublet_doublet_score', basis='umap', color_type="continuous")

# %%
adata.file.close()
